# %%
import pandas as pd
df = pd.read_csv("data.csv",encoding='latin1',header=0)
df.shape
# Out:
# (18207, 89)

# %%
df.describe()
# Out:
#          Unnamed: 0       Overall     Potential         Value       Special  \
# count  18207.000000  18206.000000  18207.000000  1.820700e+04  18207.000000
# mean    9103.000000     66.237449     71.307299  2.410696e+06   1597.809908
# std     5256.052511      6.907059      6.136496  5.594933e+06    272.586016
# min        0.000000     46.000000     48.000000  0.000000e+00    731.000000
# 25%     4551.500000     62.000000     67.000000  3.000000e+05   1457.000000
# 50%     9103.000000     66.000000     71.000000  6.750000e+05   1635.000000
# 75%    13654.500000     71.000000     75.000000  2.000000e+06   1787.000000
# max    18206.000000     94.000000     95.000000  1.185000e+08   2346.000000
#
#        International Reputation   Skill Moves      Crossing     Finishing  \
# count              18159.000000  18159.000000  18159.000000  18159.000000
# mean                   1.113222      2.361308     49.734181     45.550911
# ...

# %%
# Out:
#                      Name   Wage        Value
# 0                L. Messi  565K  110500000.0
# 1       Cristiano Ronaldo  405K   77000000.0
# 2               Neymar Jr  290K  118500000.0
# 3                  De Gea  260K   72000000.0
# 4            K. De Bruyne  355K  102000000.0
# ...                   ...    ...          ...
# 18202        J. Lundstram    1K      60000.0
# 18203  N. Christoffersson    1K      60000.0
# 18204           B. Worman    1K      60000.0
# 18205      D. Walker-Rice    1K      60000.0
# 18206           G. Nugent    1K      60000.0
#
# [18207 rows x 3 columns]
